# %% [markdown]
# ## Generate total dataset

# %%
import os
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', 1000)


with open('Core_set/LUSC/lusc_mirna_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_mirna = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_mirna = pd.concat([df_kirc_mirna, df_tmp], axis=0)
        ct+=1

with open('Core_set/LUSC/lusc_mrna_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_mrna = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_mrna = pd.concat([df_kirc_mrna, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/LUSC/lusc_clinical_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_clinical = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_clinical = pd.concat([df_kirc_clinical, df_tmp], axis=0)
        ct+=1

with open('Core_set/LUSC/lusc_rppa_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_rppa = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_rppa = pd.concat([df_kirc_rppa, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/LUSC/lusc_os_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_os = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_os = pd.concat([df_kirc_os, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/LUSC/lusc_cnv_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_cnv = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_cnv = pd.concat([df_kirc_cnv, df_tmp], axis=0)
        ct+=1
        
df_kirc = pd.merge(df_kirc_mirna, df_kirc_mrna, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_clinical, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_rppa, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_os, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_cnv, on='feature', how='left')
df_kirc.to_csv('df_lusc.csv')

# %%
import os
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', 1000)

with open('Core_set/GBM/gbm_methylation_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_met = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_met = pd.concat([df_kirc_met, df_tmp], axis=0)
        ct+=1

with open('Core_set/GBM/gbm_mirna_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_mirna = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_mirna = pd.concat([df_kirc_mirna, df_tmp], axis=0)
        ct+=1

with open('Core_set/GBM/gbm_mrna_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_mrna = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_mrna = pd.concat([df_kirc_mrna, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/GBM/gbm_clinical_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_clinical = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_clinical = pd.concat([df_kirc_clinical, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/GBM/gbm_os_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_os = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_os = pd.concat([df_kirc_os, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/GBM/gbm_cnv_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_cnv = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_cnv = pd.concat([df_kirc_cnv, df_tmp], axis=0)
        ct+=1
        
df_kirc = pd.merge(df_kirc_mirna, df_kirc_mrna, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_clinical, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_rppa, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_os, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_cnv, on='feature', how='left')
df_kirc.to_csv('df_gbm.csv')

# %%
import os
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', 1000)

with open('Core_set/OV/ov_methylation_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_met = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_met = pd.concat([df_kirc_met, df_tmp], axis=0)
        ct+=1

with open('Core_set/OV/ov_mirna_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_mirna = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_mirna = pd.concat([df_kirc_mirna, df_tmp], axis=0)
        ct+=1

with open('Core_set/OV/ov_mrna_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_mrna = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_mrna = pd.concat([df_kirc_mrna, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/OV/ov_clinical_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_clinical = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_clinical = pd.concat([df_kirc_clinical, df_tmp], axis=0)
        ct+=1

with open('Core_set/OV/ov_rppa_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_rppa = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_rppa = pd.concat([df_kirc_rppa, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/OV/ov_os_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_os = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_os = pd.concat([df_kirc_os, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/OV/ov_cnv_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_cnv = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_cnv = pd.concat([df_kirc_cnv, df_tmp], axis=0)
        ct+=1
        
df_kirc = pd.merge(df_kirc_mirna, df_kirc_mrna, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_clinical, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_rppa, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_os, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_cnv, on='feature', how='left')
df_kirc.to_csv('df_ov.csv')

# %%
import os
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
pd.set_option('display.max_columns', 1000)

with open('Core_set/KIRC/kirc_methylation_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_met = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_met = pd.concat([df_kirc_met, df_tmp], axis=0)
        ct+=1

with open('Core_set/KIRC/kirc_mirna_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_mirna = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_mirna = pd.concat([df_kirc_mirna, df_tmp], axis=0)
        ct+=1

with open('Core_set/KIRC/kirc_mrna_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_mrna = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_mrna = pd.concat([df_kirc_mrna, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/KIRC/kirc_clinical_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_clinical = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_clinical = pd.concat([df_kirc_clinical, df_tmp], axis=0)
        ct+=1

with open('Core_set/KIRC/kirc_rppa_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_rppa = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_rppa = pd.concat([df_kirc_rppa, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/KIRC/kirc_os_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_os = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_os = pd.concat([df_kirc_os, df_tmp], axis=0)
        ct+=1
        
with open('Core_set/KIRC/kirc_cnv_core.txt') as f:
    ct = 0
    for i in f.readlines():
        if ct  == 0:
            col_kirc = pd.Series(i.strip().split('\t'))
            df_kirc_cnv = pd.DataFrame(columns=col_kirc)
        else:
            df_tmp = pd.DataFrame([dict(zip(col_kirc, i.strip().split('\t')))])
            df_kirc_cnv = pd.concat([df_kirc_cnv, df_tmp], axis=0)
        ct+=1
        
df_kirc = pd.merge(df_kirc_mirna, df_kirc_mrna, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_clinical, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_rppa, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_os, on='feature', how='left')
df_kirc = pd.merge(df_kirc, df_kirc_cnv, on='feature', how='left')
df_kirc.to_csv('df_kirc.csv')

# %% [markdown]
# ## Add label

# %%
import pandas as pd

projects = ['ov', 'kirc', 'lusc', 'gbm']
for project in projects:
    df = pd.read_csv('df_%s.csv' %project, index_col='Unnamed: 0')

    with open('Binary/%s_binary_survival.txt' %project) as f:
        ct = 0
        for i in f.readlines():
            if ct  == 0:
                col = pd.Series(i.strip().split('\t'))
                df_ans = pd.DataFrame(columns=col)
            else:
                df_tmp = pd.DataFrame([dict(zip(col, i.strip().split('\t')))])
                df_ans = pd.concat([df_ans, df_tmp], axis=0)
            ct+=1
    df_ans.head()
    print(len(df_ans))
    
    df = pd.merge(df, df_ans, on='feature', how='left')
    df.to_csv('df_%s_with_ans.csv' %project)
# Out:
# 252
# 150
# 77
# 155

# %% [markdown]
# ## Split into Train and Test

# %%
import pandas as pd

df_ov = pd.read_csv('df_ov_with_ans.csv', index_col=['Unnamed: 0'])
df_kirc = pd.read_csv('df_kirc_with_ans.csv', index_col=['Unnamed: 0'])
df_lusc = pd.read_csv('df_lusc_with_ans.csv', index_col=['Unnamed: 0'])
df_gbm = pd.read_csv('df_gbm_with_ans.csv', index_col=['Unnamed: 0'])

# %%
project = 'ov'

with open('%s_train_sample_list.txt' %project) as f:
    list_train = f.read().split()
    tmp_set = set(list_train)
    print('total number of train file: %s' %len(list_train))
    print('unique number of train file: %s' %len(tmp_set))
    
with open('%s_test_sample_list.txt' %project) as f:
    list_test = f.read().split()
    tmp_set = set(list_test)
    print('total number of test file: %s' %len(list_test))
    print('unique number of test file: %s' %len(tmp_set))
    
df_train = pd.DataFrame({'feature':pd.Series(list_train)})
df_test = pd.DataFrame({'feature':pd.Series(list_test)})

df_train_tmp = pd.merge(df_train, df_ov, on='feature', how='inner')
df_train_tmp = df_train_tmp.groupby(by='feature', as_index=False).first()

df_train_tmp[df_train_tmp['is_alive'].isna() == False]
df_train_tmp[df_train_tmp['is_alive'].isna() == True]

df_test_tmp = pd.merge(df_test, df_ov, on='feature', how='inner')
df_test_tmp = df_test_tmp.groupby(by='feature', as_index=False).first()

print('label with no NaN: %s' %len(df_test_tmp[df_train_tmp['is_alive'].isna() == False]))
print('label with NaN: %s' %len(df_test_tmp[df_train_tmp['is_alive'].isna() == True]))
# Out:
# total number of train file: 30000
# unique number of train file: 379
# total number of test file: 7500
# unique number of test file: 379
# label with no NaN: 252
# label with NaN: 127

# %%
project = 'kirc'

with open('%s_train_sample_list.txt' %project) as f:
    list_train = f.read().split()
    tmp_set = set(list_train)
    print('total number of train file: %s' %len(list_train))
    print('unique number of train file: %s' %len(tmp_set))
    
with open('%s_test_sample_list.txt' %project) as f:
    list_test = f.read().split()
    tmp_set = set(list_test)
    print('total number of test file: %s' %len(list_test))
    print('unique number of test file: %s' %len(tmp_set))
    
df_train = pd.DataFrame({'feature':pd.Series(list_train)})
df_test = pd.DataFrame({'feature':pd.Series(list_test)})

df_train_tmp = pd.merge(df_train, df_kirc, on='feature', how='inner')
df_train_tmp = df_train_tmp.groupby(by='feature', as_index=False).first()

df_train_tmp[df_train_tmp['is_alive'].isna() == False]
df_train_tmp[df_train_tmp['is_alive'].isna() == True]

df_test_tmp = pd.merge(df_test, df_kirc, on='feature', how='inner')
df_test_tmp = df_test_tmp.groupby(by='feature', as_index=False).first()

print('label with no NaN: %s' %len(df_test_tmp[df_train_tmp['is_alive'].isna() == False]))
print('label with NaN: %s' %len(df_test_tmp[df_train_tmp['is_alive'].isna() == True]))
# Out:
# total number of train file: 19200
# unique number of train file: 243
# total number of test file: 4800
# unique number of test file: 243
# label with no NaN: 150
# label with NaN: 93

# %%
project = 'lusc'

with open('%s_train_sample_list.txt' %project) as f:
    list_train = f.read().split()
    tmp_set = set(list_train)
    print('total number of train file: %s' %len(list_train))
    print('unique number of train file: %s' %len(tmp_set))
    
with open('%s_test_sample_list.txt' %project) as f:
    list_test = f.read().split()
    tmp_set = set(list_test)
    print('total number of test file: %s' %len(list_test))
    print('unique number of test file: %s' %len(tmp_set))
    
df_train = pd.DataFrame({'feature':pd.Series(list_train)})
df_test = pd.DataFrame({'feature':pd.Series(list_test)})

df_train_tmp = pd.merge(df_train, df_lusc, on='feature', how='inner')
df_train_tmp = df_train_tmp.groupby(by='feature', as_index=False).first()

df_train_tmp[df_train_tmp['is_alive'].isna() == False]
df_train_tmp[df_train_tmp['is_alive'].isna() == True]

df_test_tmp = pd.merge(df_test, df_lusc, on='feature', how='inner')
df_test_tmp = df_test_tmp.groupby(by='feature', as_index=False).first()

print('label with no NaN: %s' %len(df_test_tmp[df_train_tmp['is_alive'].isna() == False]))
print('label with NaN: %s' %len(df_test_tmp[df_train_tmp['is_alive'].isna() == True]))
# Out:
# total number of train file: 9600
# unique number of train file: 121
# total number of test file: 2400
# unique number of test file: 121
# label with no NaN: 77
# label with NaN: 44

# %%
project = 'gbm'

with open('%s_train_sample_list.txt' %project) as f:
    list_train = f.read().split()
    tmp_set = set(list_train)
    print('total number of train file: %s' %len(list_train))
    print('unique number of train file: %s' %len(tmp_set))
    
with open('%s_test_sample_list.txt' %project) as f:
    list_test = f.read().split()
    tmp_set = set(list_test)
    print('total number of test file: %s' %len(list_test))
    print('unique number of test file: %s' %len(tmp_set))
    
df_train = pd.DataFrame({'feature':pd.Series(list_train)})
df_test = pd.DataFrame({'feature':pd.Series(list_test)})

df_train_tmp = pd.merge(df_train, df_gbm, on='feature', how='inner')
df_train_tmp = df_train_tmp.groupby(by='feature', as_index=False).first()

df_train_tmp[df_train_tmp['is_alive'].isna() == False]
df_train_tmp[df_train_tmp['is_alive'].isna() == True]

df_test_tmp = pd.merge(df_test, df_gbm, on='feature', how='inner')
df_test_tmp = df_test_tmp.groupby(by='feature', as_index=False).first()

print('label with no NaN: %s' %len(df_test_tmp[df_train_tmp['is_alive'].isna() == False]))
print('label with NaN: %s' %len(df_test_tmp[df_train_tmp['is_alive'].isna() == True]))
# Out:
# total number of train file: 16800
# unique number of train file: 210
# total number of test file: 4200
# unique number of test file: 210
# label with no NaN: 155
# label with NaN: 55
